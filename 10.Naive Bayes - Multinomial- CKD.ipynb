# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('CKD.csv')

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True, dtype=int)

# %%
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
# Import necessary libraries
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report

# Initialize the Multinomial Naive Bayes model
mnb = MultinomialNB()

# Define the parameter grid
param_grid = {
    'alpha': [0.1, 0.5, 1.0, 1.5, 2.0],  # Smoothing parameter
    'fit_prior': [True, False]           # Whether to learn class prior probabilities
}

# Use StratifiedKFold to maintain class balance across folds
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize GridSearchCV with Multinomial Naive Bayes, the parameter grid, and stratified cross-validation strategy
grid = GridSearchCV(estimator=mnb, param_grid=param_grid, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

# Fit the grid search to the training data
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# GridSearchCV(cv=5, estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 0.5, 1.0, 1.5, 2.0],
#                          'fit_prior': [True, False]},
#              scoring='accuracy', verbose=1)

# %%
from sklearn.metrics import f1_score

# Get the predicted labels
y_pred = grid.predict(indep)

# Calculate the F1 score using the predicted labels and the true labels
f1_macro = f1_score(dep, y_pred, average='weighted')

# Print the F1 score and the best parameters
print("The f1_macro value for best parameter {}:".format(grid.best_params_), f1_macro)
# Out:
# The f1_macro value for best parameter {'alpha': 0.1, 'fit_prior': True}: 0.8912968721618211

# %%
y_pred = grid.predict(indep)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(dep, y_pred)
from sklearn.metrics import classification_report
clf_report = classification_report(dep, y_pred)
print(clf_report)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87       150
#            1       0.98      0.84      0.91       249
#
#     accuracy                           0.89       399
#    macro avg       0.88      0.91      0.89       399
# weighted avg       0.91      0.89      0.89       399
#
# [[145   5]
#  [ 39 210]]

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(dep,grid.predict_proba(indep)[:,1])
# Out:
# 0.9623025435073628

# %%
import pandas as pd
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.026878      0.014744         0.003904        0.002200         0.1
# 1       0.020537      0.008456         0.002921        0.001524         0.1
# 2       0.009719      0.006425         0.004538        0.001241         0.5
# 3       0.007032      0.001920         0.006021        0.004920         0.5
# 4       0.016118      0.016229         0.006732        0.006111         1.0
# 5       0.004722      0.001561         0.008511        0.007793         1.0
# 6       0.007158      0.001042         0.022675        0.025546         1.5
# 7       0.005417      0.000491         0.004846        0.000561         1.5
# 8       0.018918      0.018160         0.003809        0.000683         2.0
# 9       0.008231      0.002727         0.002106        0.002691         2.0
#
#   param_fit_prior                              params  split0_test_score  \
# ...
